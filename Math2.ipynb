# %%
# Task 1.1

# Множество - это совокупность объектов.

# Последовательность - это множество, которое имеет следующие друг за другом объекты, подчиняющиеся определённому математическому закону.

# На мой вгляд множество более общее, глобальное понятие. А последовательность - это частный случай множества.

# %%
# Task 1.2

# 1
# Для любого значения y, которое принадлежат отрезку от нуля до единицы включительно: функция sgn(y) = 1
# Выражение ЛОЖНО, потому что при y = 0: sgn(y) = 0
# Отрицание: одно из значений y, которое принадлежит отрезку от нуля до единицы включительно удовлетворяет функции sgn(y) != 1

# 2
# Для любого значения n, принадлежащих натуральным числам, которые больше 2-х,
# Существуют значения x, значения y, значения z, которые принадлежат натуральным числам и есть функция:
# x**n = y**n + z**n
# Если рассматривать ситуацию, что ноль является натуральным числом, то выражение ИСТИННО: при любом n > 2, y = 1 и z = 0 => x = 1
# И также при любом n > 2, y = 0 и z = 1 => x = 1
# Если рассматривать ситуацию, что ноль не является натуральным числом, то выражение ЛОЖНО: нет такой комбинации чисел, чтобы при любом значении n выполнялось равенство
# Отрицание: существует значение n, которое принадлежит множеству натуральных чисел и меньше, либо равно 2-м,
# при всех значениях x, y и z, принадлежащих натуральным числам
# выполняется: x**n != y**n + z**n

# 3
# Для любого значения x, которое принадлежит множеству вещественных чисел, 
# существует значение X, которое тоже пренадлежит множеству вещественных чисел
# при этом X > x
# Выражение ИСТИННО: для любого вещественного числа есть число больше него.
# Отрицание: существует вещественное число x, для которого все вещественные значения X меньше, либо равны x

# 4 
# Для любого значения x, которое принадлежат множеству комплексных чисел
# нет ни одного значения y, которое принадлежит множеству комплексных чисел
# чтобы выполнялось: x > y ИЛИ x < y
# Выражение ЛОЖНО. Множество комплексных чисел слишком велико, чтобы там не было числа меньше, либо больше любого другого
# Отрицание: существуют значения "x", принадлежащие множеству комплексных чисел, для которых есть только одно значение "y",
# принадлижащие множеству комплексных чисел, удовлетворяющие выражению: x = y

# 5
# Для любого значения y, принадлежащего отрезку от 0 до п/2 существует значение "e" > 0 при котором верно выражение:
# sin(y) < sin(y + e)
# Выражение ИСТИННО: для любого значения y есть значения "e", при которох sin(y) бывает и меньше и больше sin(y + e)
# Отрицание: Сущетсвуют значения y, принадлежащие отрезку от 0 до п/2, для которых можно найти любое значение "e", чтобы было верно выражение:
# sin(y) >= sin(y + e)

# 6
# Для любого значения y от 0 включительно и до п/2 не включительно, существует значение "е" > 0, для которых верно выражение:
# cos(y) > cos(y + e)
# Утверждение ИСТИННО
# Отрицание: Существует значение y от 0 включительно и до п/2 не включительно, для которого есть любое значение 'e' > 0, чтобы выполнялось выражение:
# cos(y) <= cos(y + e)

# 7
# Существует значение "x", которое не является числом
# Утверждение ИСТИННО, потому что "x" может быть символом, текстом, либо другим нечисловым значением.
# Отрицание: При любом значении "x", "x" является числом.

# %%
# Task 2.1

a = {2, 5, 7, 8, 9, 1, 1, 5}
b = {0, -1, 4, 55, 55, 55, 32, 5}

a | b # объединение
a & b # пересечение
a - b # разность
# a |= b - дополнение
a ^ b # симметрическая разность
# Out:
# {-1, 0, 1, 2, 4, 7, 8, 9, 32, 55}
